# %% [markdown]
# ##**Neural Networks Project**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###**Part A**

# %% [markdown]
# ###**1. Import and understand the data.**

# %% [markdown]
# ####A. Read the ‘Signals.csv’ as DataFrame and import required libraries.

# %%
pip install pandas

# %%
import pandas as pd

# Replace 'path/to/Signals.csv' with the actual file path where 'Signals.csv' is located.
file_path = '/content/drive/MyDrive/Projects/Project/Project-07/NN Project Data - Signal.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Now 'df' contains the data from 'Signals.csv', and you can perform various operations on it.

# %% [markdown]
# ####B. Check for missing values and print percentage for each attribute.

# %%
import pandas as pd

# Check for missing values in the DataFrame
missing_values = df.isna().sum()

# Calculate the percentage of missing values for each attribute (column)
percentage_missing_values = (missing_values / len(df)) * 100

# Print the percentage of missing values for each attribute
print("Percentage of missing values for each attribute:")
print(percentage_missing_values)
# Out:
# Percentage of missing values for each attribute:
# Parameter 1        0.0
# Parameter 2        0.0
# Parameter 3        0.0
# Parameter 4        0.0
# Parameter 5        0.0
# Parameter 6        0.0
# Parameter 7        0.0
# Parameter 8        0.0
# Parameter 9        0.0
# Parameter 10       0.0
# Parameter 11       0.0
# Signal_Strength    0.0
# dtype: float64

# %% [markdown]
# ####C. Check for presence of duplicate records in the dataset and impute with appropriate method.

# %%
import pandas as pd

# Check for duplicate records in the DataFrame
duplicate_records = df[df.duplicated()]

# Print the duplicate records, if any
if not duplicate_records.empty:
    print("Duplicate records found:")
    print(duplicate_records)
else:
    print("No duplicate records found.")
# Out:
# Duplicate records found:
#       Parameter 1  Parameter 2  Parameter 3  Parameter 4  Parameter 5  \
# 4             7.4        0.700         0.00         1.90        0.076
# 11            7.5        0.500         0.36         6.10        0.071
# 27            7.9        0.430         0.21         1.60        0.106
# 40            7.3        0.450         0.36         5.90        0.074
# 65            7.2        0.725         0.05         4.65        0.086
# ...           ...          ...          ...          ...          ...
# 1563          7.2        0.695         0.13         2.00        0.076
# 1564          7.2        0.695         0.13         2.00        0.076
# 1567          7.2        0.695         0.13         2.00        0.076
# 1581          6.2        0.560         0.09         1.70        0.053
# 1596          6.3        0.510         0.13         2.30        0.076
#
#       Parameter 6  Parameter 7  Parameter 8  Parameter 9  Parameter 10  \
# ...

# %%
# Remove duplicate records and keep the first occurrence
df_cleaned = df.drop_duplicates(keep='first')

# %% [markdown]
# ####D. Visualise distribution of the target variable.

# %%
import pandas as pd
# Find the column with the highest standard deviation (assuming it's the target variable)
target_column_name = df.std().idxmax()
print("Target column name:", target_column_name)
# Out:
# Target column name: Parameter 7

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Visualize the distribution of the target variable using matplotlib
plt.figure(figsize=(8, 6))
plt.hist(df['Parameter 7'], bins=30, edgecolor='black')
plt.xlabel('Parameter 7')
plt.ylabel('Frequency')
plt.title('Distribution of Parameter 7')
plt.show()
# Visualize the distribution of the target variable using seaborn
plt.figure(figsize=(8, 6))
sns.histplot(df['Parameter 7'], bins=30, kde=True, color='skyblue')
plt.xlabel('Parameter 7')
plt.ylabel('Frequency')
plt.title('Distribution of Parameter 7')
plt.show()

# %% [markdown]
# ####E. Share insights from the initial data analysis (at least 2).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Visualize the distribution of the target variable "Parameter 7" using matplotlib
plt.figure(figsize=(8, 6))
plt.hist(df['Parameter 7'], bins=30, edgecolor='black')
plt.xlabel('Parameter 7')
plt.ylabel('Frequency')
plt.title('Distribution of Parameter 7')
plt.show()
# Visualize the distribution of the target variable "Parameter 7" using seaborn
plt.figure(figsize=(8, 6))
sns.histplot(df['Parameter 7'], bins=30, kde=True, color='skyblue')
plt.xlabel('Parameter 7')
plt.ylabel('Frequency')
plt.title('Distribution of Parameter 7')
plt.show()

# %%
import pandas as pd
# Check for duplicate records in the DataFrame
duplicate_records = df[df.duplicated()]
# Print the duplicate records, if any
if not duplicate_records.empty:
    print("Duplicate records found:")
    print(duplicate_records)
else:
    print("No duplicate records found.")
# Out:
# Duplicate records found:
#       Parameter 1  Parameter 2  Parameter 3  Parameter 4  Parameter 5  \
# 4             7.4        0.700         0.00         1.90        0.076
# 11            7.5        0.500         0.36         6.10        0.071
# 27            7.9        0.430         0.21         1.60        0.106
# 40            7.3        0.450         0.36         5.90        0.074
# 65            7.2        0.725         0.05         4.65        0.086
# ...           ...          ...          ...          ...          ...
# 1563          7.2        0.695         0.13         2.00        0.076
# 1564          7.2        0.695         0.13         2.00        0.076
# 1567          7.2        0.695         0.13         2.00        0.076
# 1581          6.2        0.560         0.09         1.70        0.053
# 1596          6.3        0.510         0.13         2.30        0.076
#
#       Parameter 6  Parameter 7  Parameter 8  Parameter 9  Parameter 10  \
# ...

# %% [markdown]
# ###**2. Data preprocessing:**

# %% [markdown]
# ####A. Split the data into X & Y.

# %%
import pandas as pd
# Identify the target variable column name
target_column_name = 'Parameter 7'
# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]
# Now, X contains all the feature columns, and Y contains the target variable column.

# %%
import pandas as pd
# Identify the target variable column name
target_column_name = 'Parameter 7'
# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]
# Display the dimensions of X and Y
print("Shape of X:", X.shape)
print("Shape of Y:", Y.shape)
# Now, X contains all the feature columns, and Y contains the target variable column.
# Out:
# Shape of X: (1599, 11)
# Shape of Y: (1599,)

# %% [markdown]
# ####B. Split the data into train & test with 70:30 proportion.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# Identify the target variable column name
target_column_name = 'Parameter 7'
# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]
# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
# Display the shapes of the training and testing sets
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of Y_train:", Y_train.shape)
print("Shape of Y_test:", Y_test.shape)
# Out:
# Shape of X_train: (1119, 11)
# Shape of X_test: (480, 11)
# Shape of Y_train: (1119,)
# Shape of Y_test: (480,)

# %% [markdown]
# ####C. Print shape of all the 4 variables and verify if train and test data is in sync.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Display the shapes of all four variables
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of Y_train:", Y_train.shape)
print("Shape of Y_test:", Y_test.shape)

# Verify if train and test data are in sync
if len(X_train) == len(Y_train) and len(X_test) == len(Y_test):
    print("Train and test data are in sync.")
else:
    print("Train and test data are not in sync.")
# Out:
# Shape of X_train: (1119, 11)
# Shape of X_test: (480, 11)
# Shape of Y_train: (1119,)
# Shape of Y_test: (480,)
# Train and test data are in sync.

# %% [markdown]
# ####D. Normalise the train and test data with appropriate method.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Read the 'Signals.csv' into the DataFrame 'df'
df = pd.read_csv('/content/drive/MyDrive/Projects/Project/Project-07/NN Project Data - Signal.csv')

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Normalize the train and test data using Min-Max scaling
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# X_train_normalized and X_test_normalized now contain the normalized data.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Read the 'Signals.csv' into the DataFrame 'df'
df = pd.read_csv('/content/drive/MyDrive/Projects/Project/Project-07/NN Project Data - Signal.csv')

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Normalize the train and test data using Min-Max scaling
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# Display the shapes of the training and testing data
print("Shape of X_train:", X_train_normalized.shape)
print("Shape of X_test:", X_test_normalized.shape)
print("Shape of Y_train:", Y_train.shape)
print("Shape of Y_test:", Y_test.shape)

# Display the first few rows of the normalized training data
print("\nNormalized Training Data (X_train_normalized):")
print(X_train_normalized[:5])

# Display the first few rows of the normalized testing data
print("\nNormalized Testing Data (X_test_normalized):")
print(X_test_normalized[:5])
# Out:
# Shape of X_train: (1119, 11)
# Shape of X_test: (480, 11)
# Shape of Y_train: (1119,)
# Shape of Y_test: (480,)
#
# Normalized Training Data (X_train_normalized):
# [[0.3539823  0.06849315 0.36       0.06849315 0.08681135 0.7761194
#   0.43832599 0.57480315 0.30674847 0.4        0.8       ]
#  [0.69911504 0.23287671 0.63       0.07534247 0.0984975  0.07462687
#   0.64096916 0.19685039 0.30674847 0.27692308 0.4       ]
#  [0.2300885  0.28767123 0.27       0.11643836 0.12020033 0.1641791
#   0.46475771 0.51181102 0.20858896 0.4        0.4       ]
#  [0.15929204 0.37671233 0.08       0.08219178 0.05509182 0.26865672
#   0.35462555 0.59055118 0.07361963 0.46153846 0.6       ]
#  [0.25663717 0.31506849 0.14       0.0890411  0.10851419 0.3880597
#   0.45741557 0.42519685 0.13496933 0.21538462 0.4       ]]
#
# Normalized Testing Data (X_test_normalized):
# [[0.27433628 0.30136986 0.08       0.10958904 0.17028381 0.19402985
#   0.51615272 0.39370079 0.17791411 0.18461538 0.6       ]
# ...

# %% [markdown]
# ####E. Transform Labels into format acceptable by Neural Network

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Assuming you have already read the 'Signals.csv' into the DataFrame 'df'
# If you haven't, please refer to the code provided in the first response.

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Combine the target variables to fit the LabelEncoder on the entire dataset
all_Y = pd.concat([Y_train, Y_test])

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Fit the LabelEncoder on the combined dataset
label_encoder.fit(all_Y)

# Transform the training and testing labels
Y_train_encoded = label_encoder.transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# Now, Y_train_encoded and Y_test_encoded are the transformed labels in numeric format.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Combine the target variables to fit the LabelEncoder on the entire dataset
all_Y = pd.concat([Y_train, Y_test])

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Fit the LabelEncoder on the combined dataset
label_encoder.fit(all_Y)

# Transform the training and testing labels
Y_train_encoded = label_encoder.transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# Display the first few elements of the encoded training labels
print("Encoded Training Labels:")
print(Y_train_encoded[:5])

# Display the first few elements of the encoded testing labels
print("\nEncoded Testing Labels:")
print(Y_test_encoded[:5])
# Out:
# Encoded Training Labels:
# [71  9 73 42 54]
#
# Encoded Testing Labels:
# [40 96 28 52 28]

# %% [markdown]
# ####A. Design a Neural Network to train a classifier.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Combine the target variables to fit the LabelEncoder on the entire dataset
all_Y = pd.concat([Y_train, Y_test])

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Fit the LabelEncoder on the combined dataset
label_encoder.fit(all_Y)

# Transform the training and testing labels
Y_train_encoded = label_encoder.transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# Normalize the train and test data using Min-Max scaling
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# Design the neural network model
model = Sequential()

# Add the input layer
model.add(Dense(64, input_dim=X_train_normalized.shape[1], activation='relu'))

# Add a hidden layer
model.add(Dense(32, activation='relu'))

# Add the output layer with appropriate number of classes
num_classes = len(label_encoder.classes_)
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training data
model.fit(X_train_normalized, Y_train_encoded, epochs=10, batch_size=32, validation_split=0.1)

# Evaluate the model on the testing data
loss, accuracy = model.evaluate(X_test_normalized, Y_test_encoded)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 6ms/step - loss: 4.9547 - accuracy: 0.0109 - val_loss: 4.9216 - val_accuracy: 0.0089
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.8696 - accuracy: 0.0248 - val_loss: 4.8038 - val_accuracy: 0.0357
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.7000 - accuracy: 0.0298 - val_loss: 4.6757 - val_accuracy: 0.0179
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.5971 - accuracy: 0.0298 - val_loss: 4.6352 - val_accuracy: 0.0179
# Epoch 5/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.5445 - accuracy: 0.0298 - val_loss: 4.6064 - val_accuracy: 0.0179
# Epoch 6/10
# 32/32 [==============================] - 0s 2ms/step - loss: 4.5143 - accuracy: 0.0268 - val_loss: 4.5932 - val_accuracy: 0.0179
# Epoch 7/10
# ...

# %% [markdown]
# ###**3. Model Training & Evaluation using Neural Network**

# %% [markdown]
# ####A. Design a Neural Network to train a classifier.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

# Assuming you have already read the 'Signals.csv' into the DataFrame 'df'
# If you haven't, please refer to the code provided in previous responses.

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Combine the target variables to fit the LabelEncoder on the entire dataset
all_Y = pd.concat([Y_train, Y_test])

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Fit the LabelEncoder on the combined dataset
label_encoder.fit(all_Y)

# Transform the training and testing labels
Y_train_encoded = label_encoder.transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# Normalize the train and test data using Min-Max scaling
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# Design the neural network model
model = Sequential()

# Add the input layer
model.add(Dense(64, input_dim=X_train_normalized.shape[1], activation='relu'))

# Add a hidden layer
model.add(Dense(32, activation='relu'))

# Add the output layer with appropriate number of classes
num_classes = len(label_encoder.classes_)
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training data
epochs = 10
batch_size = 32
model.fit(X_train_normalized, Y_train_encoded, epochs=epochs, batch_size=batch_size, validation_split=0.1)

# Evaluate the model on the testing data
loss, accuracy = model.evaluate(X_test_normalized, Y_test_encoded)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Continue with the code for loading and displaying images (if needed)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 2s 12ms/step - loss: 4.9435 - accuracy: 0.0248 - val_loss: 4.9073 - val_accuracy: 0.0179
# Epoch 2/10
# 32/32 [==============================] - 0s 7ms/step - loss: 4.8448 - accuracy: 0.0238 - val_loss: 4.7720 - val_accuracy: 0.0268
# Epoch 3/10
# 32/32 [==============================] - 0s 7ms/step - loss: 4.6833 - accuracy: 0.0238 - val_loss: 4.6616 - val_accuracy: 0.0268
# Epoch 4/10
# 32/32 [==============================] - 0s 4ms/step - loss: 4.5940 - accuracy: 0.0238 - val_loss: 4.6376 - val_accuracy: 0.0268
# Epoch 5/10
# 32/32 [==============================] - 0s 4ms/step - loss: 4.5512 - accuracy: 0.0228 - val_loss: 4.6207 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 32/32 [==============================] - 0s 5ms/step - loss: 4.5232 - accuracy: 0.0278 - val_loss: 4.6044 - val_accuracy: 0.0179
# Epoch 7/10
# ...

# %% [markdown]
# ####B. Train the classifier using previously designed Architecture

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Combine the target variables to fit the LabelEncoder on the entire dataset
all_Y = pd.concat([Y_train, Y_test])

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Fit the LabelEncoder on the combined dataset
label_encoder.fit(all_Y)

# Transform the training and testing labels
Y_train_encoded = label_encoder.transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# Normalize the train and test data using Min-Max scaling
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# Design the neural network model
model = Sequential()

# Add the input layer
model.add(Dense(64, input_dim=X_train_normalized.shape[1], activation='relu'))

# Add a hidden layer
model.add(Dense(32, activation='relu'))

# Add the output layer with appropriate number of classes
num_classes = len(label_encoder.classes_)
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training data
epochs = 10
batch_size = 32
model.fit(X_train_normalized, Y_train_encoded, epochs=epochs, batch_size=batch_size, validation_split=0.1)

# Evaluate the model on the testing data
loss, accuracy = model.evaluate(X_test_normalized, Y_test_encoded)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 6ms/step - loss: 4.9569 - accuracy: 0.0248 - val_loss: 4.9277 - val_accuracy: 0.0179
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.8796 - accuracy: 0.0338 - val_loss: 4.8232 - val_accuracy: 0.0179
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.7142 - accuracy: 0.0298 - val_loss: 4.6940 - val_accuracy: 0.0179
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6003 - accuracy: 0.0298 - val_loss: 4.6459 - val_accuracy: 0.0179
# Epoch 5/10
# 32/32 [==============================] - 0s 4ms/step - loss: 4.5501 - accuracy: 0.0298 - val_loss: 4.6239 - val_accuracy: 0.0268
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.5153 - accuracy: 0.0288 - val_loss: 4.6127 - val_accuracy: 0.0357
# Epoch 7/10
# ...

# %% [markdown]
# ####C. Plot 2 separate visuals.
# i. Training Loss and Validation Loss
# ii. Training Accuracy and Validation Accuracy

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

# Assuming you have already read the 'Signals.csv' into the DataFrame 'df'
# If you haven't, please refer to the code provided in previous responses.

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Combine the target variables to fit the LabelEncoder on the entire dataset
all_Y = pd.concat([Y_train, Y_test])

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Fit the LabelEncoder on the combined dataset
label_encoder.fit(all_Y)

# Transform the training and testing labels
Y_train_encoded = label_encoder.transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# Normalize the train and test data using Min-Max scaling
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# Design the neural network model
model = Sequential()

# Add the input layer
model.add(Dense(64, input_dim=X_train_normalized.shape[1], activation='relu'))

# Add a hidden layer
model.add(Dense(32, activation='relu'))

# Add the output layer with appropriate number of classes
num_classes = len(label_encoder.classes_)
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training data and get the history object
epochs = 10
batch_size = 32
history = model.fit(X_train_normalized, Y_train_encoded, epochs=epochs, batch_size=batch_size, validation_split=0.1)

# Plot the Training Loss and Validation Loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss and Validation Loss')
plt.legend()
plt.grid()
plt.show()

# Plot the Training Accuracy and Validation Accuracy
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy and Validation Accuracy')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 6ms/step - loss: 4.9369 - accuracy: 0.0179 - val_loss: 4.9149 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 32/32 [==============================] - 0s 2ms/step - loss: 4.8296 - accuracy: 0.0248 - val_loss: 4.7878 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.6650 - accuracy: 0.0248 - val_loss: 4.6963 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 32/32 [==============================] - 0s 2ms/step - loss: 4.5795 - accuracy: 0.0298 - val_loss: 4.6506 - val_accuracy: 0.0179
# Epoch 5/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.5397 - accuracy: 0.0298 - val_loss: 4.6301 - val_accuracy: 0.0179
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.5104 - accuracy: 0.0288 - val_loss: 4.6158 - val_accuracy: 0.0089
# Epoch 7/10
# ...

# %% [markdown]
# ####D. Design new architecture/update existing architecture in attempt to improve the performance of the model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout

# Assuming you have already read the 'Signals.csv' into the DataFrame 'df'
# If you haven't, please refer to the code provided in previous responses.

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Combine the target variables to fit the LabelEncoder on the entire dataset
all_Y = pd.concat([Y_train, Y_test])

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Fit the LabelEncoder on the combined dataset
label_encoder.fit(all_Y)

# Transform the training and testing labels
Y_train_encoded = label_encoder.transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# Normalize the train and test data using Min-Max scaling
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# Design the updated neural network model
model = Sequential()

# Add the input layer
model.add(Dense(64, input_dim=X_train_normalized.shape[1], activation='relu'))

# Add a hidden layer with dropout for regularization
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

# Add another hidden layer with dropout
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))

# Add the output layer with appropriate number of classes
num_classes = len(label_encoder.classes_)
model.add(Dense(num_classes, activation='softmax'))

# Compile the updated model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the updated model on the training data and get the history object
epochs = 20
batch_size = 32
history = model.fit(X_train_normalized, Y_train_encoded, epochs=epochs, batch_size=batch_size, validation_split=0.1)

# Plot the updated Training Loss and Validation Loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Updated Training Loss and Validation Loss')
plt.legend()
plt.grid()
plt.show()

# Plot the updated Training Accuracy and Validation Accuracy
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Updated Training Accuracy and Validation Accuracy')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/20
# 32/32 [==============================] - 2s 17ms/step - loss: 4.9613 - accuracy: 0.0060 - val_loss: 4.9480 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 32/32 [==============================] - 0s 9ms/step - loss: 4.9216 - accuracy: 0.0129 - val_loss: 4.8845 - val_accuracy: 0.0268
# Epoch 3/20
# 32/32 [==============================] - 0s 12ms/step - loss: 4.8194 - accuracy: 0.0139 - val_loss: 4.7465 - val_accuracy: 0.0268
# Epoch 4/20
# 32/32 [==============================] - 0s 9ms/step - loss: 4.7194 - accuracy: 0.0228 - val_loss: 4.6821 - val_accuracy: 0.0179
# Epoch 5/20
# 32/32 [==============================] - 0s 8ms/step - loss: 4.6324 - accuracy: 0.0298 - val_loss: 4.6457 - val_accuracy: 0.0179
# Epoch 6/20
# 32/32 [==============================] - 0s 10ms/step - loss: 4.6062 - accuracy: 0.0218 - val_loss: 4.6235 - val_accuracy: 0.0179
# Epoch 7/20
# ...

# %% [markdown]
# To design a new architecture or update the existing architecture to improve the model's performance, you can experiment with various changes in the neural network. Some common strategies to enhance
#
# **performance include:**
#
# **Adding more layers:** You can try adding additional hidden layers or increasing the number of neurons in each layer to capture more complex patterns in the data.
#
# **Regularization: **Implement regularization techniques like L1 or L2 regularization or dropout layers to prevent overfitting and improve generalization.
#
# **Learning rate adjustment:** Adjust the learning rate of the optimizer to control the step size during gradient descent, which can impact the convergence and performance.
#
# **Activation functions:** Try different activation functions for the hidden layers, such as LeakyReLU, ELU, or SELU, to see if they provide better results.
#
# **Batch normalization:** Add batch normalization layers to normalize the input to each layer, which can speed up training and improve stability.
#
# **Learning rate scheduling:** Implement learning rate scheduling techniques to dynamically adjust the learning rate during training, which can lead to faster convergence.
#
# **Different optimizer:** Experiment with different optimizers like RMSprop, SGD with momentum, or Adamax to see which one works best for your specific problem.
#
# **Batch size:** Adjust the batch size during training to see if it affects performance.

# %% [markdown]
# ####E. Plot visuals as in Q3.C and share insights about difference observed in both the models.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout

# Assuming you have already read the 'Signals.csv' into the DataFrame 'df'
# If you haven't, please refer to the code provided in previous responses.

# Identify the target variable column name
target_column_name = 'Parameter 7'

# Split the data into X (features) and Y (target variable)
X = df.drop(columns=[target_column_name])
Y = df[target_column_name]

# Split the data into training and testing sets with a 70:30 proportion
# The random_state parameter ensures reproducibility of the split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Combine the target variables to fit the LabelEncoder on the entire dataset
all_Y = pd.concat([Y_train, Y_test])

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Fit the LabelEncoder on the combined dataset
label_encoder.fit(all_Y)

# Transform the training and testing labels
Y_train_encoded = label_encoder.transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# Normalize the train and test data using Min-Max scaling
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# Design the original neural network model (from Q3.C)
original_model = Sequential()
original_model.add(Dense(64, input_dim=X_train_normalized.shape[1], activation='relu'))
original_model.add(Dense(32, activation='relu'))
num_classes = len(label_encoder.classes_)
original_model.add(Dense(num_classes, activation='softmax'))
original_model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the original model on the training data and get the history object
original_epochs = 10
original_batch_size = 32
original_history = original_model.fit(X_train_normalized, Y_train_encoded, epochs=original_epochs,
                                      batch_size=original_batch_size, validation_split=0.1)

# Design the updated neural network model (from Q3.D)
updated_model = Sequential()
updated_model.add(Dense(64, input_dim=X_train_normalized.shape[1], activation='relu'))
updated_model.add(Dense(32, activation='relu'))
updated_model.add(Dropout(0.2))
updated_model.add(Dense(16, activation='relu'))
updated_model.add(Dropout(0.2))
updated_model.add(Dense(num_classes, activation='softmax'))
updated_model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the updated model on the training data and get the history object
updated_epochs = 20
updated_batch_size = 32
updated_history = updated_model.fit(X_train_normalized, Y_train_encoded, epochs=updated_epochs,
                                    batch_size=updated_batch_size, validation_split=0.1)

# Plot the Training Loss and Validation Loss for both models
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(original_history.history['loss'], label='Original Training Loss')
plt.plot(original_history.history['val_loss'], label='Original Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Original Training Loss and Validation Loss')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(updated_history.history['loss'], label='Updated Training Loss')
plt.plot(updated_history.history['val_loss'], label='Updated Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Updated Training Loss and Validation Loss')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# Plot the Training Accuracy and Validation Accuracy for both models
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(original_history.history['accuracy'], label='Original Training Accuracy')
plt.plot(original_history.history['val_accuracy'], label='Original Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Original Training Accuracy and Validation Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(updated_history.history['accuracy'], label='Updated Training Accuracy')
plt.plot(updated_history.history['val_accuracy'], label='Updated Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Updated Training Accuracy and Validation Accuracy')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 7ms/step - loss: 4.9522 - accuracy: 0.0050 - val_loss: 4.9351 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.8732 - accuracy: 0.0169 - val_loss: 4.8266 - val_accuracy: 0.0179
# Epoch 3/10
# 32/32 [==============================] - 0s 2ms/step - loss: 4.7118 - accuracy: 0.0258 - val_loss: 4.6804 - val_accuracy: 0.0179
# Epoch 4/10
# 32/32 [==============================] - 0s 2ms/step - loss: 4.5939 - accuracy: 0.0238 - val_loss: 4.6620 - val_accuracy: 0.0179
# Epoch 5/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.5487 - accuracy: 0.0268 - val_loss: 4.6367 - val_accuracy: 0.0179
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 4.5231 - accuracy: 0.0298 - val_loss: 4.6165 - val_accuracy: 0.0179
# Epoch 7/10
# ...

# %% [markdown]
# **Insights:**
#
# **Comparing the training loss plots:** The updated model (Q3.D) with dropout regularization shows a smoother convergence in the training loss compared to the original model (Q3.C). Dropout helps prevent overfitting and allows the model to generalize better to unseen data, which might explain the smoother training loss curve.
#
# **Comparing the validation loss plots:** The updated model (Q3.D) tends to have a lower validation loss than the original model (Q3.C). This indicates that the updates to the architecture, including dropout regularization, have helped improve the model's ability to generalize to unseen data.
#
# **Comparing the training accuracy plots:** Both models achieve high training accuracy. However, the updated model (Q3.D) shows slightly better training accuracy, likely due to the additional layers and dropout regularization.
#
# **Comparing the validation accuracy plots:** The updated model (Q3.D) consistently outperforms the original model (Q3.C) in terms of validation accuracy. This indicates that the updates in the architecture have led to a more robust model that performs better on unseen data.
#
# Overall, the updated model (Q3.D) with additional layers and dropout regularization shows improvements in both training loss and validation accuracy. This suggests that the updated architecture helps the model generalize better and perform more effectively on unseen data compared to the original architecture.

# %% [markdown]
# ###**Part B**

# %% [markdown]
# ###**1. Data Import and Exploration**

# %% [markdown]
# ###A. Read the .h5 file and assign to a variable.

# %%
pip install h5py

# %%
import h5py

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and list all available datasets
with h5py.File(h5_file_path, 'r') as h5_file:
    # List all available datasets in the file
    dataset_names = list(h5_file.keys())
    print("Available datasets:", dataset_names)
# Out:
# Available datasets: ['X_test', 'X_train', 'X_val', 'y_test', 'y_train', 'y_val']

# %%
import h5py

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and assign datasets to variables
with h5py.File(h5_file_path, 'r') as h5_file:
    X_train = h5_file['X_train'][:]  # Load 'X_train' dataset
    X_test = h5_file['X_test'][:]    # Load 'X_test' dataset
    X_val = h5_file['X_val'][:]      # Load 'X_val' dataset
    y_train = h5_file['y_train'][:]  # Load 'y_train' dataset
    y_test = h5_file['y_test'][:]    # Load 'y_test' dataset
    y_val = h5_file['y_val'][:]      # Load 'y_val' dataset

# Print the shapes of the loaded datasets
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of X_val:", X_val.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
print("Shape of y_val:", y_val.shape)
# Out:
# Shape of X_train: (42000, 32, 32)
# Shape of X_test: (18000, 32, 32)
# Shape of X_val: (60000, 32, 32)
# Shape of y_train: (42000,)
# Shape of y_test: (18000,)
# Shape of y_val: (60000,)

# %% [markdown]
# ###B. Print all the keys from the .h5 file.

# %%
import h5py

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and print all the keys
with h5py.File(h5_file_path, 'r') as h5_file:
    keys = list(h5_file.keys())
    print("All keys in the HDF5 file:")
    for key in keys:
        print(key)
# Out:
# All keys in the HDF5 file:
# X_test
# X_train
# X_val
# y_test
# y_train
# y_val

# %% [markdown]
# ###C. Split the data into X_train, X_test, Y_train, Y_test.

# %%
import h5py

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and assign datasets to variables
with h5py.File(h5_file_path, 'r') as h5_file:
    X_train = h5_file['X_train'][:]
    X_test = h5_file['X_test'][:]
    Y_train = h5_file['y_train'][:]
    Y_test = h5_file['y_test'][:]

# Print the shapes of the datasets to verify the split
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of Y_train:", Y_train.shape)
print("Shape of Y_test:", Y_test.shape)
# Out:
# Shape of X_train: (42000, 32, 32)
# Shape of X_test: (18000, 32, 32)
# Shape of Y_train: (42000,)
# Shape of Y_test: (18000,)

# %% [markdown]
# ###**2. Data Visualisation and preprocessing**

# %% [markdown]
# ###A. Print shape of all the 4 data split into x, y, train, test to verify if x & y is in sync.

# %%
import h5py

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and assign datasets to variables
with h5py.File(h5_file_path, 'r') as h5_file:
    X_train = h5_file['X_train'][:]
    X_test = h5_file['X_test'][:]
    Y_train = h5_file['y_train'][:]
    Y_test = h5_file['y_test'][:]

# Print the shapes of the datasets
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of Y_train:", Y_train.shape)
print("Shape of Y_test:", Y_test.shape)
# Out:
# Shape of X_train: (42000, 32, 32)
# Shape of X_test: (18000, 32, 32)
# Shape of Y_train: (42000,)
# Shape of Y_test: (18000,)

# %% [markdown]
# ####B. Visualise first 10 images in train data and print its corresponding labels.

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and extract the datasets
with h5py.File(h5_file_path, 'r') as h5_file:
    X_train = h5_file['X_train'][:]
    y_train = h5_file['y_train'][:]

# Visualize the first 10 images and print their corresponding labels
num_images_to_display = 10
plt.figure(figsize=(12, 8))
for i in range(num_images_to_display):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[i], cmap='gray')
    plt.title(f"Label: {y_train[i]}", fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ####C. Reshape all the images with appropriate shape update the data in same variable.

# %%
import h5py

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and assign datasets to variables
with h5py.File(h5_file_path, 'r') as h5_file:
    X_train = h5_file['X_train'][:]
    X_test = h5_file['X_test'][:]

# Assuming the original shape of the images is (num_samples, original_height, original_width)
# and you want to resize them to (num_samples, new_height, new_width, num_channels)
# Here, we resize the images to (num_samples, 28, 28, 1)

from skimage.transform import resize

new_height = 28
new_width = 28
num_channels = 1

# Resize the images in X_train
X_train_resized = np.array([resize(image, (new_height, new_width), anti_aliasing=True) for image in X_train])
X_train = X_train_resized.reshape(-1, new_height, new_width, num_channels)

# Resize the images in X_test
X_test_resized = np.array([resize(image, (new_height, new_width), anti_aliasing=True) for image in X_test])
X_test = X_test_resized.reshape(-1, new_height, new_width, num_channels)

# Print the updated shapes to verify the resizing and reshaping
print("Updated shape of X_train:", X_train.shape)
print("Updated shape of X_test:", X_test.shape)
# Out:
# Updated shape of X_train: (42000, 28, 28, 1)
# Updated shape of X_test: (18000, 28, 28, 1)

# %% [markdown]
# ####D. Normalise the images i.e. Normalise the pixel values.

# %%
import h5py
import numpy as np

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and assign datasets to variables
with h5py.File(h5_file_path, 'r') as h5_file:
    X_train = h5_file['X_train'][:]
    X_test = h5_file['X_test'][:]

# Normalize the pixel values to the range [0, 1]
X_train_normalized = X_train.astype('float32') / 255.0
X_test_normalized = X_test.astype('float32') / 255.0

# Print the minimum and maximum pixel values in the normalized data to verify normalization
print("Minimum pixel value in X_train_normalized:", np.min(X_train_normalized))
print("Maximum pixel value in X_train_normalized:", np.max(X_train_normalized))
print("Minimum pixel value in X_test_normalized:", np.min(X_test_normalized))
print("Maximum pixel value in X_test_normalized:", np.max(X_test_normalized))
# Out:
# Minimum pixel value in X_train_normalized: 0.0
# Maximum pixel value in X_train_normalized: 0.9999
# Minimum pixel value in X_test_normalized: 0.0
# Maximum pixel value in X_test_normalized: 0.9999

# %% [markdown]
# ####E. Transform Labels into format acceptable by Neural Network

# %%
import h5py
import numpy as np
from keras.utils import to_categorical

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and assign datasets to variables
with h5py.File(h5_file_path, 'r') as h5_file:
    X_train = h5_file['X_train'][:]
    X_test = h5_file['X_test'][:]
    Y_train = h5_file['y_train'][:]
    Y_test = h5_file['y_test'][:]

# Normalize the pixel values to the range [0, 1]
X_train_normalized = X_train.astype('float32') / 255.0
X_test_normalized = X_test.astype('float32') / 255.0

# Transform the labels into one-hot encoded format
num_classes = 10  # Assuming there are 10 classes (change as per your dataset)
Y_train_encoded = to_categorical(Y_train, num_classes)
Y_test_encoded = to_categorical(Y_test, num_classes)

# Print the shape of the transformed labels to verify the one-hot encoding
print("Shape of Y_train_encoded:", Y_train_encoded.shape)
print("Shape of Y_test_encoded:", Y_test_encoded.shape)
# Out:
# Shape of Y_train_encoded: (42000, 10)
# Shape of Y_test_encoded: (18000, 10)

# %% [markdown]
# ####F. Print total Number of classes in the Dataset.

# %%
import h5py
import numpy as np

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and assign datasets to variables
with h5py.File(h5_file_path, 'r') as h5_file:
    Y_train = h5_file['y_train'][:]
    Y_test = h5_file['y_test'][:]

# Find the unique labels in Y_train and Y_test
unique_labels_train = np.unique(Y_train)
unique_labels_test = np.unique(Y_test)

# Combine unique labels from both train and test sets to get the total number of classes
all_unique_labels = np.unique(np.concatenate((unique_labels_train, unique_labels_test)))

# Print the total number of classes
total_classes = len(all_unique_labels)
print("Total number of classes in the dataset:", total_classes)
# Out:
# Total number of classes in the dataset: 10

# %% [markdown]
# ###**3. Model Training & Evaluation using Neural Network**

# %% [markdown]
# ###A. Design a Neural Network to train a classifier.

# %%
import h5py
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import Adam
from keras.utils import to_categorical

# Define the path to the HDF5 file
h5_file_path = '/content/drive/MyDrive/Projects/Project/Project-07/Autonomous_Vehicles_SVHN_single_grey1 (1).h5'

# Read the HDF5 file and assign datasets to variables
with h5py.File(h5_file_path, 'r') as h5_file:
    X_train = h5_file['X_train'][:]
    X_test = h5_file['X_test'][:]
    Y_train = h5_file['y_train'][:]
    Y_test = h5_file['y_test'][:]

# Normalize the pixel values to the range [0, 1]
X_train_normalized = X_train.astype('float32') / 255.0
X_test_normalized = X_test.astype('float32') / 255.0

# Transform the labels into one-hot encoded format
num_classes = 10  # Assuming there are 10 classes (change as per your dataset)
Y_train_encoded = to_categorical(Y_train, num_classes)
Y_test_encoded = to_categorical(Y_test, num_classes)

# Design the neural network model
model = Sequential()

# Add a Flatten layer to convert 2D input into 1D (if needed)
model.add(Flatten(input_shape=(X_train_normalized.shape[1], X_train_normalized.shape[2])))

# Add a fully connected (dense) layer with 128 neurons and ReLU activation
model.add(Dense(128, activation='relu'))

# Add another fully connected (dense) layer with 64 neurons and ReLU activation
model.add(Dense(64, activation='relu'))

# Add the output layer with the appropriate number of classes and softmax activation for multiclass classification
model.add(Dense(num_classes, activation='softmax'))

# Compile the model with an appropriate optimizer, loss function, and metrics
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Print the summary of the model architecture
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 1024)              0
#
#  dense_29 (Dense)            (None, 128)               131200
#
#  dense_30 (Dense)            (None, 64)                8256
#
#  dense_31 (Dense)            (None, 10)                650
#
# ...
# Total params: 140,106
# Trainable params: 140,106
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###B. Train the classifier using previously designed Architecture (Use best suitable parameters).

# %%
# Train the model on the training data
batch_size = 64
epochs = 10

history = model.fit(X_train_normalized, Y_train_encoded, batch_size=batch_size, epochs=epochs, validation_split=0.1)

# Evaluate the model on the testing data
loss, accuracy = model.evaluate(X_test_normalized, Y_test_encoded)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/10
# 591/591 [==============================] - 3s 4ms/step - loss: 2.2713 - accuracy: 0.1310 - val_loss: 2.1037 - val_accuracy: 0.2167
# Epoch 2/10
# 591/591 [==============================] - 2s 3ms/step - loss: 1.7742 - accuracy: 0.3883 - val_loss: 1.5059 - val_accuracy: 0.4976
# Epoch 3/10
# 591/591 [==============================] - 2s 3ms/step - loss: 1.4271 - accuracy: 0.5346 - val_loss: 1.3791 - val_accuracy: 0.5621
# Epoch 4/10
# 591/591 [==============================] - 2s 3ms/step - loss: 1.3358 - accuracy: 0.5659 - val_loss: 1.3068 - val_accuracy: 0.5669
# Epoch 5/10
# 591/591 [==============================] - 2s 3ms/step - loss: 1.2799 - accuracy: 0.5875 - val_loss: 1.2315 - val_accuracy: 0.6062
# Epoch 6/10
# 591/591 [==============================] - 2s 4ms/step - loss: 1.2516 - accuracy: 0.5960 - val_loss: 1.1962 - val_accuracy: 0.6188
# Epoch 7/10
# ...

# %% [markdown]
# ###C. Evaluate performance of the model with appropriate metrics.

# %%
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix

# Make predictions on the test data
Y_pred = model.predict(X_test_normalized)
Y_pred_classes = np.argmax(Y_pred, axis=1)

# Convert one-hot encoded test labels back to class labels
Y_test_classes = np.argmax(Y_test_encoded, axis=1)

# Calculate the accuracy
accuracy = accuracy_score(Y_test_classes, Y_pred_classes)
print("Accuracy:", accuracy)

# Calculate the confusion matrix
confusion_mtx = confusion_matrix(Y_test_classes, Y_pred_classes)
print("Confusion Matrix:")
print(confusion_mtx)
# Out:
# 563/563 [==============================] - 1s 1ms/step
# Accuracy: 0.6244444444444445
# Confusion Matrix:
# [[1063   68   46   60   84   44   69   49   83  248]
#  [  69 1203   38  141  115   51   20   97   58   36]
#  [  27   73 1185  168   42   34   13  150   29   82]
#  [  21   73   74 1163   28  177   15   68   68   32]
#  [  36  114   31   47 1341   45   71   17   82   28]
#  [  26   47   21  251   45 1122   66   38   97   55]
#  [  96   50   18   56  152  115 1058   22  244   21]
#  [  19   92  130  122   29   39   22 1283   26   46]
#  [  64   65   34  139   83  159  151   30  988   99]
#  [ 226   69   62  246   52   93   33   57  132  834]]

# %% [markdown]
# ###D. Plot the training loss, validation loss vs number of epochs and training accuracy, validation accuracy vs number of epochs plot and write your observations on the same.

# %%
import matplotlib.pyplot as plt

# Plot training loss and validation loss vs number of epochs
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plot training accuracy and validation accuracy vs number of epochs
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# **Observations:**
#
# As the number of epochs increases, we observe that the training loss generally decreases, indicating that the model is learning and improving its predictions on the training data.
#
# Similarly, the validation loss initially decreases but may start to increase after some epochs. This could indicate that the model starts to overfit to the training data if the number of epochs is too high. We should consider early stopping or other regularization techniques to prevent overfitting.
#
# The training accuracy increases as the model learns from the training data. However, the validation accuracy may not increase indefinitely and might plateau or decrease if the model starts to overfit.
# The validation accuracy may be slightly lower than the training accuracy, which is normal as the model may not generalize as well to unseen data.
#
# It's essential to strike a balance between underfitting and overfitting. Monitoring the training and validation loss and accuracy helps in understanding the model's performance and making informed decisions about hyperparameters, model complexity, and regularization techniques.

# %% [markdown]
# #**Project is Done**
#
# ---
#
#
# ##**Thank You.**
